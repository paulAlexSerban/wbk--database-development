# %% [markdown]
# # Seed PostgreSQL
#
# Runs the same seed logic as `make seed` (shared `scripts/` package).
#
# Run `make compose_up`, then open this notebook at `http://localhost:8888`.

# %%
from scripts.seed import (
    seed,
    seed_customers,
    seed_order_items,
    seed_orders,
    seed_users,
)

# %% [markdown]
# ## Full seed
#
# Creates/recreates tables and inserts users, customers, orders, and order items.

# %%
seed()

# %% [markdown]
# ## Partial seed (optional)
#
# Run individual steps if you want to reseed one table at a time.
# Respect foreign-key order: customers → orders → order_items.

# %%
# seed_users()
# seed_customers()
# seed_orders()
# seed_order_items()
